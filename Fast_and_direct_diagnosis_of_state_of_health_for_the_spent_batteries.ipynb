# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor, LGBMClassifier

import os, copy, random, pickle, seaborn, datetime, shap

# %%
#!pip install pycaret # for feature selection

# %% [markdown]
# # SoC classification

# %%
raw_data = pd.read_csv('./SoC data.csv', index_col=0)

# dVi == dV0-0.1s, dVf == dV0.1-10s, dV == dV0-10s, Vi == V0.1s, Vf == V10s
col = ['OCV', 'dVi', 'dVf', 'dV', 'Vi', 'Vf', 'skew', 'kurt']

soc_data = pd.DataFrame()
for i in range(0, 100+1, 5):
    temp = pd.DataFrame()
    temp['soc'] = [i]*len(raw_data)
    for j in col:
        temp[j] = list(raw_data['{}_{}'.format(i, j)])

    if i < 10:
        temp['soc_class'] = [0]*len(raw_data)
    elif i < 80:
        temp['soc_class'] = [1]*len(raw_data)
    else:
        temp['soc_class'] = [2]*len(raw_data)

    soc_data = pd.concat([soc_data, temp])

mms_classification = MinMaxScaler()
mms_classification.fit(soc_data[col])
data_transform = pd.DataFrame(mms_classification.transform(soc_data[col]), columns=col)
data_transform['soc'] = list(soc_data['soc'])
data_transform['soc_class'] = list(soc_data['soc_class'])

corr = list(data_transform.corr()['soc'].sort_values(key=abs, ascending=False).keys())[1:]
temp_corr = data_transform.corr()
temp_corr = temp_corr.loc[corr, corr]

t_feature_col = copy.deepcopy(col)
for i in t_feature_col:
    if (np.isnan(data_transform.corr().loc[i, 'soc'])):
        t_feature_col.remove(i)

protocol_feature_col = copy.deepcopy(t_feature_col)
for i in range(len(t_feature_col)):
    t = []
    for j in range(i+1, len(protocol_feature_col)):
        if (abs(temp_corr.loc[protocol_feature_col[i], protocol_feature_col[j]]) > 0.75):
            t.append(protocol_feature_col[j])
    for j in t:
        protocol_feature_col.remove(j)

print('features after removing highly correlated feature : {}'.format(protocol_feature_col))

feature = ['soc_class']+protocol_feature_col
data_transform = data_transform[feature]

opt_classification = LGBMClassifier(verbose=-1, learning_rate=0.19763117861267274, n_estimators=101, max_depth=3, min_child_samples=100, min_child_weight=1.1424465350768398, num_leaves=150, colsample_bytree=0.6634449816853505, subsample=0.8639560911474804, reg_alpha=0.3345612399250176, reg_lambda=1.955106417669215)
opt_classification.fit(data_transform[protocol_feature_col], data_transform['soc_class'])
# Out:
# features after removing highly correlated feature : ['OCV', 'dVi', 'dVf', 'skew']
# LGBMClassifier(colsample_bytree=0.6634449816853505,
#                learning_rate=0.19763117861267274, max_depth=3,
#                min_child_samples=100, min_child_weight=1.1424465350768398,
#                n_estimators=101, num_leaves=150, reg_alpha=0.3345612399250176,
#                reg_lambda=1.955106417669215, subsample=0.8639560911474804,
#                verbose=-1)

# %%
test_size = 0.15

temp_X_train, temp_X_test, temp_y_train, temp_y_test = train_test_split(raw_data, raw_data['100_OCV'], test_size=test_size)
protocol_feature_col = ['OCV', 'dVi', 'dVf', 'skew']

train = pd.DataFrame()
c = 0
for i in temp_X_train.index:
    for soc in range(0, 100+1, 5):
        if soc >= 80:
            train.loc[c, 'soc_class'] = 2
        elif soc >= 10:
            train.loc[c, 'soc_class'] = 1
        elif soc >= 0:
            train.loc[c, 'soc_class'] = 0

        train.loc[c, 'soc'] = soc
        for k in col:
            train.loc[c, k] = temp_X_train.loc[i, '{}_{}'.format(soc, k)]

        c += 1

test = pd.DataFrame()
c = 0
for i in temp_X_test.index:
    for soc in range(0, 100+1, 5):
        if soc >= 80:
            test.loc[c, 'soc_class'] = 2
        elif soc >= 10:
            test.loc[c, 'soc_class'] = 1
        elif soc >= 0:
            test.loc[c, 'soc_class'] = 0

        test.loc[c, 'soc'] = soc
        for k in col:
            test.loc[c, k] = temp_X_test.loc[i, '{}_{}'.format(soc, k)]

        c += 1

mms = MinMaxScaler()
mms.fit(train[col])
train_data_transform = pd.DataFrame(mms.transform(train[col]), columns=col)
train_data_transform['soc_class'] = train['soc_class']
train_data_transform['soc'] = train['soc']

test_data_transform = pd.DataFrame(mms.transform(test[col]), columns=col)
test_data_transform['soc_class'] = test['soc_class']
test_data_transform['soc'] = test['soc']

opt_classification = LGBMClassifier(verbose=-1, learning_rate=0.19763117861267274, n_estimators=101, max_depth=3, min_child_samples=100, min_child_weight=1.1424465350768398, num_leaves=150, colsample_bytree=0.6634449816853505, subsample=0.8639560911474804, reg_alpha=0.3345612399250176, reg_lambda=1.955106417669215)
opt_classification.fit(train_data_transform[protocol_feature_col], train_data_transform['soc_class'])

train_score = metrics.accuracy_score(train_data_transform['soc_class'], opt_classification.predict(train_data_transform[protocol_feature_col]))
test_score = metrics.accuracy_score(test_data_transform['soc_class'], opt_classification.predict(test_data_transform[protocol_feature_col]))
print('Accucary : (train) {} (test) {}'.format(round(train_score, 3), round(test_score, 3)))

plt.scatter(train_data_transform['soc'], opt_classification.predict(train_data_transform[protocol_feature_col]), alpha=0.5, label='train')
plt.scatter(test_data_transform['soc'], opt_classification.predict(test_data_transform[protocol_feature_col]), alpha=0.5, label='test')
plt.legend()
plt.show()
# Out:
# Accucary : (train) 1.0 (test) 1.0

# %%
feature_col = ['OCV', 'dVi', 'dVf', 'skew']

opt_classification = LGBMClassifier(verbose=-1, learning_rate=0.19763117861267274, n_estimators=101, max_depth=3, min_child_samples=100, min_child_weight=1.1424465350768398, num_leaves=150, colsample_bytree=0.6634449816853505, subsample=0.8639560911474804, reg_alpha=0.3345612399250176, reg_lambda=1.955106417669215)
opt_classification.fit(data_transform[protocol_feature_col], data_transform['soc_class'])

tree_explainer = shap.TreeExplainer(opt_classification)
shap_values = tree_explainer.shap_values(data_transform[protocol_feature_col], data_transform['soc_class'])

for class_idx in range(3):
    print(f"Class {class_idx} summary plot:")
    shap.summary_plot(shap_values[:, :, class_idx], data_transform[protocol_feature_col], show=True)
# Out:
# Class 0 summary plot:
# Class 1 summary plot:
# Class 2 summary plot:

# %% [markdown]
# # SoH regression

# %%
# This is feature generation code from raw data in 'SoH_protocol' folder, and generates 'SoH_features.xlsx' file.
# Thus, you don't need to excute this code due to this file is already generated the folder.

# category = {0 : [['char', 'dischar'], ['pulse', 'rest'], [100, 95, 90, 85, 80], [float(x) for x in [1.65, 2]]],
#             1 : [['char', 'dischar'], ['pulse', 'rest'], [75, 70, 65, 60], [float(x) for x in [1.65, 2]]],
#             2 : [['char', 'dischar'], ['pulse', 'rest'], [55, 50, 45, 40, 35, 30, 25, 20, 15, 10], [float(x) for x in [1.65, 2]]],
#             3 : [['char', 'dischar'], ['pulse', 'rest'], [5, 0], [float(x) for x in [1.65, 2]]]}

# file_list = []
# path_1 = './SoH_protocol/'
# for file_0 in os.listdir(path_1):
#     for file_1 in os.listdir(path_1+file_0):
#         file_list.append('{}{}/{}'.format(path_1, file_0, file_1))

# soh = pd.read_csv('./SoH.csv', index_col=0)
# resistance = pd.read_csv('./SoH_resistance.csv', index_col=0)
# ir_drop = pd.read_csv('./SoH_ir_drop.csv', index_col=0)

# cycle = soh.columns
# with pd.ExcelWriter('./SoH_features.xlsx') as writer:
#     for e in range(4):
#         for a in category[e][2]:
#             temp = pd.DataFrame()
#             for file in soh.index:
#                 for cyc in cycle:
#                     temp_path='{}{}/'.format(path_1, cyc)
#                     if '{}_{}.csv'.format(file, cyc) in os.listdir(temp_path):
#                         DCPR = pd.read_csv('{}{}.csv'.format(temp_path, file))
#                         for x, c in enumerate(category[e][3]):
#                             for d in category[e][1]:
#                                 for b in category[e][0]:
#                                     temp_volt = []
#                                     for z, y in enumerate(DCPR['{}_{}C_{}_{}'.format(a, c, b, d)]):
#                                         temp_volt.append(y)
#                                         if (y > 4.2) or (y < 2.5):
#                                             if DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+1] == DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+1]:
#                                                 temp_volt.append(DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+1])
#                                             if DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+2] == DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+2]:
#                                                 temp_volt.append(DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+2])
#                                             if DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+3] == DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+3]:
#                                                 temp_volt.append(DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+3])
#                                             break
#                                         elif y != y:
#                                             del temp_volt[-1]
#                                             break

#                                     temp.loc['{}_{}'.format(file, cyc), 'SoH'] = soh.loc[file, cyc]
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_kurt'.format(c, b, d)] = pd.DataFrame(temp_volt)[0].kurt()
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_skew'.format(c, b, d)] = pd.DataFrame(temp_volt)[0].skew()
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_initial'.format(c, b, d)] = temp_volt[0]
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_final'.format(c, b, d)] = temp_volt[-1]
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_R'.format(c, b, d)] = resistance.loc[file, '{}_{}_{}C_{}_{}'.format(cyc, a, c, b, d)]
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_IR'.format(c, b, d)] = ir_drop.loc['{}_{}'.format(file, cyc), '{}_{}C_{}_{}'.format(a, c, b, d)]

#                                     if b == 'char':
#                                         if a >= 10:
#                                             temp.loc['{}_{}'.format(file, cyc), '{} C_{}_R_ratio'.format(c, d)] = resistance.loc[file, '{}_{}_{}C_char_{}'.format(cyc, a, c, d)]/resistance.loc[file, '{}_{}_{}C_dischar_{}'.format(cyc, a, c, d)]
#                                         else:
#                                             temp.loc['{}_{}'.format(file, cyc), '{} C_{}_R_ratio'.format(c, d)] = resistance.loc[file, '{}_{}_{}C_dischar_{}'.format(cyc, a, c, d)]/resistance.loc[file, '{}_{}_{}C_char_{}'.format(cyc, a, c, d)]

#                                         if d == 'pulse':
#                                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_time'.format(c, b, d)] = len(temp_volt)/10

#                                 if d == 'pulse':
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_hysteresis'.format(c, d)] = (max(DCPR['{}_{}C_char_{}'.format(a, c, d)])-min(DCPR['{}_{}C_dischar_{}'.format(a, c, d)]))/crate_current[str(c)]

#                             for j in category[e][3][x+1:]:
#                                 for b in category[e][0]:
#                                     if resistance.loc[file, '{}_{}_{}C_{}_{}'.format(cyc, a, c, b, d)] == 0.0:
#                                         temp.loc['{}_{}'.format(file, cyc), '{} C_R/{} C_R_{}_{}'.format(j ,c, b, d)] = 0.0
#                                     else:
#                                         temp.loc['{}_{}'.format(file, cyc), '{} C_R/{} C_R_{}_{}'.format(j ,c, b, d)] = (resistance.loc[file, '{}_{}_{}C_{}_{}'.format(cyc, a, j, b, d)]/resistance.loc[file, '{}_{}_{}C_{}_{}'.format(cyc, a, c, b, d)])

#             temp.to_excel(writer, sheet_name=str(a))

# %%
# Feature selection for SoH regression
# # # It takes several hours depending on your hardware specification.

# from pycaret import regression

# repeat = 30

# file_path = './SoH_features.xlsx'
# df = pd.DataFrame()
# for i in range(0, 100+1, 5):
#     temp = pd.read_excel(file_path, sheet_name=str(i), index_col=0)
#     df = pd.concat([df, temp])

# df = df.reset_index(drop=True)

# corr = list(df.corr()['SoH'].sort_values(key=abs, ascending=False).keys())[1:]
# temp_corr = df.corr()
# temp_corr = temp_corr.loc[corr, corr]
# ##################################
# t_feature_col = copy.deepcopy(corr)

# # tt_feature_col = copy.deepcopy(t_feature_col)
# for i in t_feature_col:
#     if (np.isnan(df.corr().loc[i, 'SoH'])):
#         t_feature_col.remove(i)

# feature_col = copy.deepcopy(t_feature_col)
# for i in range(len(t_feature_col)):
#     t = []
#     for j in range(i+1, len(feature_col)):
#         if (abs(temp_corr.loc[feature_col[i], feature_col[j]]) > 0.8):
#             t.append(feature_col[j])
#     for j in t:
#         feature_col.remove(j)

# feature_col = [i for i in feature_col if 'time' not in i]
# ##################################
# print(len(feature_col), feature_col)
# ##################################
# feature = ['SoH'] + feature_col

# mms_soh = MinMaxScaler()
# mms_soh.fit(df[feature_col])
# data_transform = pd.DataFrame(mms_soh.transform(df[feature_col]), columns=feature_col)
# data_transform['SoH'] = df['SoH']

# initial_feature_col = copy.deepcopy(feature_col)
# r2 = {}
# model = pd.DataFrame()
# for i in range(len(initial_feature_col), 1-1, -1):
#     temp_r2 = []
#     if i == len(initial_feature_col):
#         feature_col = initial_feature_col

#     for j in range(repeat):

#         feature = ['SoH'] + feature_col

#         mms_soh = MinMaxScaler()
#         mms_soh.fit(df[feature_col])
#         data_transform = pd.DataFrame(mms_soh.transform(df[feature_col]), columns=feature_col)
#         data_transform['SoH'] = df['SoH']

#         regression.setup(data_transform[feature], target='SoH', fold = 7, verbose=False)
#         ml = regression.compare_models(verbose=False, exclude=['et'])
#         temp = regression.pull()

#         if ('{}'.format(temp.index[0]) in model.index) and (i in model.columns):
#             if np.isnan(model.loc[temp.index[0], i]):
#                 model.loc['{}'.format(temp.index[0]), i] = 1
#             else:
#                 model.loc['{}'.format(temp.index[0]), i] += 1
#         else:
#             model.loc['{}'.format(temp.index[0]), i] = 1

#         temp_r2.append(temp['R2'][0])

#     r2[i] = sum(temp_r2)/repeat
#     print('The numer of selected features : {}, R2 score : {}'.format(i, r2[i]))
#     print('The selected features : {}'.format(feature_col))

#     feature_dict = {}
#     for x, y in zip(feature_col, ml.feature_importances_):
#         feature_dict[x]=y

#     feature_dict = dict(sorted(feature_dict.items(), key=lambda k: k[1], reverse=True))
#     feature_col = list(feature_dict.keys())[:-1]

# plt.plot(range(1, len(initial_feature_col)+1), [r2[i] for i in range(1, len(initial_feature_col)+1)])
# print(model)

# %%
file_path = './SoH_features.xlsx'

soh_feature_col = ['2.0 C_char_rest_IR', '1.65 C_dischar_pulse_IR', '2.0 C_pulse_hysteresis', '2.0 C_char_pulse_R', '1.65 C_dischar_pulse_R', '1.65 C_dischar_pulse_skew', '2.0 C_char_rest_skew', '2.0 C_char_pulse_final', '1.65 C_dischar_rest_skew', '2.0 C_char_pulse_skew', '2.0 C_dischar_pulse_final', '1.65 C_rest_R_ratio']

df = pd.DataFrame()
for i in range(0, 100+1, 5):
    temp = pd.read_excel(file_path, sheet_name=str(i), index_col=0)
    df = pd.concat([df, temp])

temp = temp.reset_index(drop=True)
df = df.reset_index(drop=True)

mms_soh = MinMaxScaler()
mms_soh.fit(df[soh_feature_col])

data_transform = pd.DataFrame(mms_soh.transform(df[soh_feature_col]), columns=soh_feature_col)
data_transform['SoH'] = df['SoH']

opt_soh = RandomForestRegressor(n_jobs=-1, max_depth=18, min_samples_leaf=2, min_samples_split=2, n_estimators=261, bootstrap=False, max_features=0.5)
opt_soh.fit(data_transform[soh_feature_col], data_transform['SoH'])
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=18, max_features=0.5,
#                       min_samples_leaf=2, n_estimators=261, n_jobs=-1)

# %%
train_list, test_list = [], []
train_protocol, test_protocol = [], []

for sheet in range(0, 100+1, 5):
    temp = pd.read_excel(file_path, sheet_name=str(sheet))

    train_df, test_df = train_test_split(temp, test_size=0.15, shuffle=True)

    train_list.append(train_df)
    test_list.append(test_df)

    if sheet < 10:
        train_protocol += [1]*len(train_df)
        test_protocol += [1]*len(test_df)
    elif sheet < 80:
        train_protocol += [2]*len(train_df)
        test_protocol += [2]*len(test_df)
    else:
        train_protocol += [3]*len(train_df)
        test_protocol += [3]*len(test_df)

train = pd.concat(train_list, ignore_index=True)
test = pd.concat(test_list, ignore_index=True)
#################
mms_soh = MinMaxScaler()
mms_soh.fit(df[soh_feature_col])

train_data_transform = pd.DataFrame(mms_soh.transform(train[soh_feature_col]), columns=soh_feature_col)
train_data_transform['SoH'] = list(train['SoH'])

test_data_transform = pd.DataFrame(mms_soh.transform(test[soh_feature_col]), columns=soh_feature_col)
test_data_transform['SoH'] = list(test['SoH'])

opt_soh = RandomForestRegressor(n_jobs=-1, random_state=5, max_depth=18, min_samples_leaf=2, min_samples_split=2, n_estimators=261, bootstrap=False, max_features=0.5)
opt_soh.fit(train_data_transform[soh_feature_col], train_data_transform['SoH'])

train_score = metrics.root_mean_squared_error(train['SoH'], opt_soh.predict(train_data_transform[soh_feature_col]))
test_score = metrics.root_mean_squared_error(test['SoH'], opt_soh.predict(test_data_transform[soh_feature_col]))
print('RMSE : (train) {} (test) {}'.format(round(train_score, 3), round(test_score, 3)))

train_score = metrics.r2_score(train['SoH'], opt_soh.predict(train_data_transform[soh_feature_col]))
test_score = metrics.r2_score(test['SoH'], opt_soh.predict(test_data_transform[soh_feature_col]))
print('R2 score : (train) {} (test) {}'.format(round(train_score, 3), round(test_score, 3)))
print()

print(f"전체 train shape: {train.shape}", f"전체 test shape: {test.shape}")
plt.scatter(train['SoH'], opt_soh.predict(train_data_transform[soh_feature_col]), alpha=0.5, label='train')
plt.scatter(test['SoH'], opt_soh.predict(test_data_transform[soh_feature_col]), alpha=0.5, label='test')
plt.plot([30, 105], [30, 105], 'k--')
plt.legend()
plt.show()
# Out:
# RMSE : (train) 0.404 (test) 1.286
# R2 score : (train) 0.998 (test) 0.983
#
# 전체 train shape: (18028, 60) 전체 test shape: (3193, 60)

# %%
# # It takes several hours depending on your hardware specification.

# tree_explainer = shap.TreeExplainer(opt_soh)
# shap_values = tree_explainer.shap_values(data_transform[feature_col])
# shap.summary_plot(shap_values, data_transform[soh_feature_col], show=True)

# %% [markdown]
# # Expandability

# %% [markdown]
# ## SoC classification

# %%
soc_data = pd.read_csv('./SoC data_expandability.csv', index_col=0)

# cell1=50E, cell2=M50
c=0
for z, x in enumerate(['50E', 'M50']):
    data = pd.DataFrame()
    for i in [y for y in soc_data.index if x in y]:
        for soc in range(0, 100+1, 5):
            if soc >= 80:
                data.loc[c, 'soc_class'] = 2
            elif soc >= 10:
                data.loc[c, 'soc_class'] = 1
            elif soc >= 0:
                data.loc[c, 'soc_class'] = 0

            data.loc[c, 'soc'] = soc
            for k in ['OCV', 'Vi', 'Vf', 'dVi', 'dVf', 'dV', 'skew', 'kurt']:
                if k=='dVi':
                    if '50E' in i:
                        data.loc[c, k] = soc_data.loc[i, '{}_{}'.format(soc, k)]/1.3/(202/166)+0.018
                    elif 'M50' in i:
                        data.loc[c, k] = soc_data.loc[i, '{}_{}'.format(soc, k)]/1.3/(198/166)+0.018

                elif k=='dV':
                    if '50E' in i:
                        data.loc[c, k] = soc_data.loc[i, '{}_{}'.format(soc, k)]/1.0/(202/166)+0.000
                    elif 'M50' in i:
                        data.loc[c, k] = soc_data.loc[i, '{}_{}'.format(soc, k)]/1.0/(202/166)+0.000

                else:
                    data.loc[c, k] = soc_data.loc[i, '{}_{}'.format(soc, k)]

            c += 1

    data_transform = pd.DataFrame(mms_classification.transform(data[col]), columns=col)
    data_transform['soc'] = list(data['soc'])
    data_transform['soc_class'] = list(data['soc_class'])

    plt.scatter(data['soc'], opt_classification.predict(data_transform[protocol_feature_col]), alpha=0.7, c='C{}'.format(z), label='Cell{}'.format(z+2))
    print('Accuracy for cell {} : {}'.format(z+1, metrics.accuracy_score(data['soc_class'], opt_classification.predict(data_transform[protocol_feature_col]))))


plt.plot([10, 10], [-0.5, 7.5], 'k--')
plt.plot([80, 80], [-0.5, 7.5], 'k--')
plt.xlabel('SoC', fontsize=15)
plt.ylabel('Predicted diagnostic protocol', fontsize=15)
plt.xticks(range(0, 100+1, 10), fontsize=13)
plt.yticks(range(0, 4+1), fontsize=13)
plt.ylim([-0.3, 2.3])
plt.legend()
plt.show()
# Out:
# Accuracy for cell 1 : 0.9417989417989417
# Accuracy for cell 2 : 0.9523809523809523

# %% [markdown]
# ## SoH regression

# %%
# # This is feature generation code from raw data in 'SoH_protocol_expandability' folder, and generates 'SoH_features_expandability.xlsx' file.
# # Thus, you don't need to excute this code due to this file is already generated the folder.

# crate_current_50E = {'0.1':4.9, '1.65':8.085, '2.0':9.8}
# crate_current_M50LT = {'0.1':4.8, '1.65':7.92, '2.0':9.6}

# category = {0 : [['char', 'dischar'], ['pulse', 'rest'], [100, 95, 90, 85, 80], [float(x) for x in [1.65, 2]]],
#             1 : [['char', 'dischar'], ['pulse', 'rest'], [75, 70, 65, 60], [float(x) for x in [1.65, 2]]],
#             2 : [['char', 'dischar'], ['pulse', 'rest'], [55, 50, 45, 40, 35, 30, 25, 20, 15, 10], [float(x) for x in [1.65, 2]]],
#             3 : [['char', 'dischar'], ['pulse', 'rest'], [5, 0], [float(x) for x in [1.65, 2]]]}

# file_list = []
# path_1 = '{}DCPR/'.format(path)
# for file_0 in os.listdir(path_1):
#     for file_1 in os.listdir(path_1+file_0):
#         file_list.append('{}{}/{}'.format(path_1, file_0, file_1))

# soh = pd.read_excel('./SoH_expandability.xlsx', sheet_name='SoH', index_col=0)
# resistance = pd.read_csv('./DCPR data/INR_21700/20250805_DCPR_resistance.csv', index_col=0)
# ir_drop = pd.read_csv('./DCPR data/INR_21700/20250805_DCPR_ir_drop.csv', index_col=0)

# cycle = soh.columns
# with pd.ExcelWriter('./DCPR data/INR_21700/{}_DCPR_features_21700_inverse.xlsx'.format(dt.datetime.now().strftime('%Y%m%d'))) as writer:
#     for e in range(4):
#         for a in category[e][2]:
#             temp = pd.DataFrame()
#             for file in soh.index:
#                 for cyc in cycle:
#                     temp_path='{}{}/'.format(path_1, cyc)
#                     if '{}_{}.csv'.format(file, cyc) in os.listdir(temp_path):
#                         DCPR = pd.read_csv('{}{}_{}.csv'.format(temp_path, file, cyc))
#                         for x, c in enumerate(category[e][3]):
#                             for d in category[e][1]:
#                                 for b in category[e][0]:
#                                     temp_volt = []
#                                     for z, y in enumerate(DCPR['{}_{}C_{}_{}'.format(a, c, b, d)]):
#                                         temp_volt.append(y)
#                                         if (y > 4.2) or (y < 2.5):
#                                             if DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+1] == DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+1]:
#                                                 temp_volt.append(DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+1])
#                                             if DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+2] == DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+2]:
#                                                 temp_volt.append(DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+2])
#                                             if DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+3] == DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+3]:
#                                                 temp_volt.append(DCPR['{}_{}C_{}_{}'.format(a, c, b, d)][z+3])
#                                             break
#                                         elif y != y:
#                                             del temp_volt[-1]
#                                             break

#                                     temp.loc['{}_{}'.format(file, cyc), 'SoH'] = soh.loc[file, cyc]
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_kurt'.format(c, b, d)] = pd.DataFrame(temp_volt)[0].kurt()
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_skew'.format(c, b, d)] = pd.DataFrame(temp_volt)[0].skew()
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_initial'.format(c, b, d)] = temp_volt[0]
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_final'.format(c, b, d)] = temp_volt[-1]
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_R'.format(c, b, d)] = resistance.loc[file, '{}_{}_{}C_{}_{}'.format(cyc, a, c, b, d)]
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_IR'.format(c, b, d)] = ir_drop.loc['{}_{}'.format(file, cyc), '{}_{}C_{}_{}'.format(a, c, b, d)]

#                                     if b == 'char':
#                                         if a >= 10:
#                                             temp.loc['{}_{}'.format(file, cyc), '{} C_{}_R_ratio'.format(c, d)] = resistance.loc[file, '{}_{}_{}C_char_{}'.format(cyc, a, c, d)]/resistance.loc[file, '{}_{}_{}C_dischar_{}'.format(cyc, a, c, d)]
#                                         else:
#                                             temp.loc['{}_{}'.format(file, cyc), '{} C_{}_R_ratio'.format(c, d)] = resistance.loc[file, '{}_{}_{}C_dischar_{}'.format(cyc, a, c, d)]/resistance.loc[file, '{}_{}_{}C_char_{}'.format(cyc, a, c, d)]

#                                         if d == 'pulse':
#                                             temp.loc['{}_{}'.format(file, cyc), '{} C_{}_{}_time'.format(c, b, d)] = len(temp_volt)/10

#                                 if '50E' in file:
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_hysteresis'.format(c, d)] = (max(DCPR['{}_{}C_char_{}'.format(a, c, d)])-min(DCPR['{}_{}C_dischar_{}'.format(a, c, d)]))/crate_current_50E[str(c)]
#                                 elif 'M50' in file:
#                                     temp.loc['{}_{}'.format(file, cyc), '{} C_{}_hysteresis'.format(c, d)] = (max(DCPR['{}_{}C_char_{}'.format(a, c, d)])-min(DCPR['{}_{}C_dischar_{}'.format(a, c, d)]))/crate_current_M50LT[str(c)]

#                             for j in category[e][3][x+1:]:
#                                 for b in category[e][0]:
#                                     # for cyc in cycle:
#                                     if resistance.loc[file, '{}_{}_{}C_{}_{}'.format(cyc, a, c, b, d)] == 0.0:
#                                         temp.loc['{}_{}'.format(file, cyc), '{} C_R/{} C_R_{}_{}'.format(j ,c, b, d)] = 0.0
#                                     else:
#                                         temp.loc['{}_{}'.format(file, cyc), '{} C_R/{} C_R_{}_{}'.format(j ,c, b, d)] = (resistance.loc[file, '{}_{}_{}C_{}_{}'.format(cyc, a, j, b, d)]/resistance.loc[file, '{}_{}_{}C_{}_{}'.format(cyc, a, c, b, d)])


#             temp.to_excel(writer, sheet_name=str(a))
#             print(a, 'done')

# %%
result = pd.DataFrame()
for s in range(0, 100+1, 5):
    df = pd.read_excel('./SoH_features_expandability.xlsx', sheet_name=str(s), index_col=0)

    if s < 10:
        a, b, c, d, e, f =  1.0, 0.012, 0.08, 0.01, 1.1, 0.0
    elif s < 80:
        a, b, c, d, e, f = 0.8, 0.009, 0.8, 0.011, 0.5, -0.002
    else:
        a, b, c, d, e, f = 0.1, 0.011, 0.7, 0.007, 0.8, 0.0

    for i in df.columns:
        if i == '2.0 C_char_rest_IR':
            for j in df.index:
                if '50E' in j:
                    x = 202/166
                elif 'M50' in j:
                    x = 198/166

                df.loc[j, i] = df.loc[j, i]/(a*x)+b

        elif i == '1.65 C_dischar_pulse_IR':
            for j in df.index:
                if '50E' in j:
                    x = 202/166
                elif 'M50' in j:
                    x = 198/166

                df.loc[j, i] = df.loc[j, i]/(c*x)+d

        elif i == '1.65 C_dischar_pulse_R':
            for j in df.index:
                if '50E' in j:
                    x = 202/166
                elif 'M50' in j:
                    x = 198/166

                df.loc[j, i] = df.loc[j, i]/(e*x)+f

    for x, i in enumerate(df.index):
        result.loc[i, s] = opt_soh.predict(pd.DataFrame(mms_soh.transform(df[soh_feature_col]), columns=soh_feature_col))[x]

    for x, i in enumerate(df.index):
        result.loc[i, 'SoH'] = df.loc[i, 'SoH']

for c, i in enumerate(['50E', 'M50']):
    temp = result.loc[[x for x in result.index if i in x], :]
    true, predict = [], []
    for i in range(0, 100+1, 5):
        for j in temp.index:
            if temp.loc[j, i] == temp.loc[j, i]:
                true.append(temp.loc[j, 'SoH'])
                predict.append(temp.loc[j, i])

    rmse = metrics.root_mean_squared_error(true, predict)
    mae = metrics.mean_absolute_error(true, predict)
    mape = metrics.mean_absolute_percentage_error(true, predict)*100

    print('Cell {} : (RMSE) {} (MAE) {} (MAPE) {}'.format(c+1, round(rmse, 3), round(mae, 3), round(mape, 3)))


plt.figure(figsize=(5, 5))
plt.plot([55, 103], [55, 103], 'k--')
for c, i in enumerate(['50E', 'M50']):
    temp = result.loc[[x for x in result.index if i in x], :]
    for s in range(0, 100+1, 5):
        if s == 0:
            plt.scatter(temp['SoH'], temp[s], alpha=0.7, c='C{}'.format(c), label='Cell{}'.format(c+2))

        else:
            plt.scatter(temp['SoH'], temp[s], alpha=0.7, c='C{}'.format(c))

plt.legend()
plt.show()
# Out:
# Cell 1 : (RMSE) 2.765 (MAE) 2.243 (MAPE) 2.812
# Cell 2 : (RMSE) 3.217 (MAE) 2.411 (MAPE) 2.724
